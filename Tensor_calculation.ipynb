# %%
import numpy as np
import torch

# %%
tensor = torch.ones(2, 2)

# %%
np_array = tensor.numpy()
np_array
# Out:
# array([[1., 1.],
#        [1., 1.]], dtype=float32)

# %%
np_array2 = np.array(tensor)
np_array2
# Out:
# array([[1., 1.],
#        [1., 1.]], dtype=float32)

# %%
tensor[0, 0] = -1

# %%
print(f'numpy() result\n{np_array}\n')
print(f'np.array() result\n{np_array2}')
''' tensor 객체의 numpy 메서드를 쓴 경우는 메모리 공유 '''
# Out:
# numpy() result
# [[-1.  1.]
#  [ 1.  1.]]
#
# np.array() result
# [[1. 1.]
#  [1. 1.]]

# %%
a = torch.tensor([[1, 2],
                  [3, 4]])
b = torch.tensor([[1, 1],
                  [2, 2]])

# %%
a + b
# Out:
# tensor([[2, 3],
#         [5, 6]])

# %%
torch.add(a, b)
# Out:
# tensor([[2, 3],
#         [5, 6]])

# %%
a * b
# Out:
# tensor([[1, 2],
#         [6, 8]])

# %%
torch.multiply(a, b)
# Out:
# tensor([[1, 2],
#         [6, 8]])

# %%
a = torch.tensor(
    [
        [1, 2],
        [3, 4],
        [5, 6],
        [7, 8],
    ]
)
b = torch.tensor(
    [
        [1, 0, 0],
        [0, 0, 1],
        [1, 1, 0],
    ]
)

print(f'a의 열 개수: {a.shape[1]}')
print(f'b의 행 개수: {b.shape[0]}')
# Out:
# a의 열 개수: 2
# b의 행 개수: 3

# %%
torch.matmul(a, b)
'''오류난 이유 행과 열의 개수가 달라서'''
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_608/3511122213.py in <cell line: 0>()
# ----> 1 torch.matmul(a, b)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (4x2 and 3x3)

# %%
a = torch.tensor(
    [
        [1, 2],
        [3, 4],
        [5, 6],
        [7, 8],
    ]
)
b = torch.tensor(
    [
        [1, 0, 0],
        [0, 0, 1],
    ]
)

print(f'a의 열 개수: {a.shape[1]}')
print(f'b의 행 개수: {b.shape[0]}')
# Out:
# a의 열 개수: 2
# b의 행 개수: 2

# %%
torch.matmul(a, b)
# Out:
# tensor([[1, 0, 2],
#         [3, 0, 4],
#         [5, 0, 6],
#         [7, 0, 8]])

# %%
a @ b
# Out:
# tensor([[1, 0, 2],
#         [3, 0, 4],
#         [5, 0, 6],
#         [7, 0, 8]])

# %%
tensor_int = torch.tensor([1, 2], dtype=torch.int32)
tensor_float = torch.tensor([3, 4], dtype=torch.float32)

add_result = tensor_int + tensor_float
mul_result = tensor_int * tensor_float

print(add_result)
print(mul_result)
# Out:
# tensor([4., 6.])
# tensor([3., 8.])

# %%
print(add_result.dtype)
print(mul_result.dtype)
# Out:
# torch.float32
# torch.float32

# %%
tensor_int = torch.tensor([1, 2], dtype=torch.int32)
tensor_float = torch.tensor(
    [
        [3, 1],
        [1, 4]
    ],
    dtype=torch.float32
)

torch.matmul(tensor_int, tensor_float)
''' 행렬 곱은 데이터 타입이 같아야 함'''
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_608/4189981720.py in <cell line: 0>()
#       8 )
#       9
# ---> 10 torch.matmul(tensor_int, tensor_float)
#
# RuntimeError: expected m1 and m2 to have the same dtype, but got: int != float

# %%
tensor_cast = tensor_int.to(torch.float32)

torch.matmul(tensor_cast, tensor_float)
# Out:
# tensor([5., 9.])

# %%
tensor = torch.tensor([3, 5, 7, 9, 10])

# %%
tensor[0]
# Out:
# tensor(3)

# %%
tensor[2]
# Out:
# tensor(7)

# %%
tensor[-1]
# Out:
# tensor(10)

# %%
tensor[::2]
# Out:
# tensor([ 3,  7, 10])

# %%
tensor_2d = torch.tensor(
    [
        [1, 3, 5, 7, 9],
        [2, 4, 6, 8, 10],
    ]
)

# %%
tensor_2d[0, :3]
# Out:
# tensor([1, 3, 5])

# %%
tensor_2d[0, 3:]
# Out:
# tensor([7, 9])

# %%
tensor_2d[:, 1:4]
# Out:
# tensor([[3, 5, 7],
#         [4, 6, 8]])
