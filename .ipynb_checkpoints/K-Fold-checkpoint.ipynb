# %% [markdown]
# ### K겹 교차 검증(k-fold cross validation)
#
# - 데이터 셋을 k개의 같은 사이즈로 나눈 후 이 데이터 셋을 train, test로 나눠 교차 검증
#
# ![image.png](attachment:4a3ad4c1-cbec-4f43-922a-03094c3ed200.png)

# %%
import pandas as pd
import numpy as np

from sklearn import datasets
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

''' 경고메세지 출력 방지'''
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
iris_data = datasets.load_iris()

# %%
X = pd.DataFrame(iris_data.data, columns=iris_data.feature_names)
y = pd.DataFrame(iris_data.target, columns=['Class'])

# %%
logistic_model=LogisticRegression(max_iter=2000)

# %%
''' cv=5 는 5차 교차 검증을 뜻함'''
cross_val_score(logistic_model, X, y.values.ravel(), cv=5)
# Out:
# array([0.96666667, 1.        , 0.93333333, 0.96666667, 1.        ])

# %%
np.average(cross_val_score(logistic_model, X, y.values.ravel(), cv=5))
# Out:
# np.float64(0.9733333333333334)
